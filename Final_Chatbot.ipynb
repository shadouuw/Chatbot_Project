# %%
import pandas as pd
import pandas as pd

from sklearn.svm import SVC
from sklearn.model_selection import train_test_split as tts
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder as LE
from sklearn.metrics.pairwise import cosine_similarity
from nltk.corpus import stopwords

import nltk
from nltk.corpus import stopwords

def get_database():
    from pymongo import MongoClient
    import pymongo

    # Provide the mongodb atlas url to connect python to mongodb using pymongo
    CONNECTION_STRING = "mongodb+srv://shadow:IoWeSNE9oFAdvgV4@cluster0.w2fqm.mongodb.net/API?retryWrites=true&w=majority"

    # Create a connection using MongoClient. You can import MongoClient or use pymongo.MongoClient
    from pymongo import MongoClient
    client = MongoClient(CONNECTION_STRING)

    # Create the database for our example (we will use the same database throughout the tutorial
    return client['API']
if __name__ == "__main__":
    dbname = get_database()

collection_name = dbname["chat"]


data = pd.DataFrame.from_records(collection_name.find())

# %%
questions = data['Question'].values
questions
# Out:
# array(['Hi', 'Hey', 'Is anyone there?', ...,
#        'how much is interest for Fixed Deposit', 'Fixed Deposit', 'FD'],
#       dtype=object)

# %%
stop_words = set(stopwords.words('english'))
print(stop_words)
def cleanup(sentence):
    word_tok = nltk.word_tokenize(sentence)
    stemmed_words = [w for w in word_tok if not w in stop_words]
    print(stemmed_words)

    #stemmed_words = [stemmer.stem(w) for w in word_tok]
    return ' '.join(stemmed_words)
# Out:
# {'nor', "you'll", 'between', 'off', 'been', 'my', "should've", 've', 'itself', 'hadn', 'hasn', 'them', 'ours', 'himself', 't', 'm', 'how', 'if', 'll', 'over', 'other', 'very', 'me', 'myself', 'with', 'do', 're', 'won', "mightn't", 'your', 'have', 'to', 'wasn', 'before', 'same', 'once', 'against', 'can', 'this', "needn't", 'needn', 'when', 'down', 'about', 'our', 'all', 'shan', 'these', 'no', 'themselves', "doesn't", 'am', 'yourself', 'has', "wasn't", 'yours', "weren't", 'a', 'or', "haven't", 'until', 'few', "shouldn't", 'should', "aren't", 'during', 'their', 'here', 'but', 'the', "it's", 'and', 'because', "mustn't", 'are', 'now', 'does', 'whom', 'at', 'out', 'herself', 'being', 'shouldn', 'those', 'under', 'theirs', "you're", 'each', 'doesn', "wouldn't", 'him', 'be', 'both', 'will', 'more', 'she', 'is', 'couldn', 'don', 'ain', 'ourselves', 'after', 'up', 'some', "you'd", 'from', 'her', 'd', 'aren', 'he', 'by', 'i', 'they', 'didn', 'where', 'weren', 'its', 'most', 'in', 'such', 'ma', 'that', 'yourselves', 'for', 'was', 'we', 'his', 'so', "that'll", 'above', "won't", "she's", 'had', 'having', 'isn', "shan't", 'it', 'any', 'of', 'just', 'on', 'own', "hasn't", 'below', "don't", 'wouldn', 'which', 'while', 'doing', 'mightn', 'were', 'further', "isn't", 'why', 'y', 'you', "hadn't", 'did', "didn't", 'then', 'there', 'haven', "you've", 'too', 'who', 'again', 'into', 'o', 'than', 'as', 's', 'what', "couldn't", 'hers', 'through', 'an', 'mustn', 'not', 'only'}

# %%
le = LE()

tfv = TfidfVectorizer(min_df=1, stop_words='english')

questions = data['Question'].values

X = []

for question in questions:
    X.append(cleanup(question))
# Out:
# ['Hi']
# ['Hey']
# ['Is', 'anyone', '?']
# ['Hello']
# ['Hay']
# ['salemo', 'aleykom']
# ['ahlaa']
# ['Bye']
# ['See', 'later']
# ['Goodbye']
# ['aya', 'ciao']
# ['Thanks']
# ['Thank']
# ['That', "'s", 'helpful']
# ['Thanks', 'help']
# ['aycho']
# ['Who', '?']
# ['?']
# ['Who', '?']
# ['chkounek', 'nti', '?']
# ['name']
# ['I', 'call']
# ['whats', 'name', '?']
# ['best', 'time', 'visit', 'office']
# ['Your', 'office', 'working', 'time']
# ['open', 'office', 'afternoon']
# ['wa9tech', 'nal9akom']
# ['Could', 'help', '?']
# ['give', 'hand', 'please']
# ['Can', 'help', '?']
# ['heelp']
# ['I', 'need', 'support']
# ['I', 'need', 'help']
# ['support', 'please']
# ['How', 'could', 'help', '?']
# []
# ['What', 'help', 'provide', '?']
# ['helpful']
# ['What', 'support', 'offered']
# ['I', 'need', 'create', 'new', 'account']
# ['open', 'new', 'account']
# ['I', 'want', 'create', 'account']
# ['complaint']
# ['I', 'want', 'raise', 'complaint']
# ['complaint', 'service']
# ['Welcome', 'back.Here', "'s", 'left', '.']
# ['Can', 'I', 'use', 'ATM', 'free', '?']
# ['What', 'happens', 'I', 'try', 'withdraw', 'money', 'I', 'account', '?']
# ['Is', 'fee', '?']
# ['Do', 'I', 'need', 'keep', 'certain', 'amount', 'money', 'account', '?']
# ['Is', 'branch', 'nearby', '?']
# ['Can', 'I', 'access', 'account', 'information', 'online', '?']
# ['Is', 'mobile', 'banking', 'available', '?']
# ['Will', 'cost', 'transfer', 'money', '?']
# ['Do', 'I', 'pay', 'checks', 'replacement', 'cards', '?']
# ['Does', 'account', 'pay', 'interest', '?']
# ['What', 'documents', 'required', 'opening', 'Current', 'Account', 'sole', 'proprietorship', 'firm']
# ['Can', 'I', 'transfer', 'Current', 'Account', 'one', 'branch', 'another']
# ['My', 'present', 'status', 'NRI', '.', 'What', 'extra', 'documents', 'required', 'opening', 'Sole', 'Proprietorship', 'Current', 'Account']
# ['What', 'documents', 'required', 'opening', 'Current', 'Account', 'Limited', 'Liability', 'Partnership']
# ['What', 'documents', 'required', 'change', 'address', 'entity']
# ['What', 'documents', 'required', 'opening', 'Current', 'Account', 'company']
# ['Who', 'partner', 'partnership', 'firm']
# ['What', 'time', 'taken', 'realize', 'outstation', 'cheques']
# ['Can', 'individual', 'open', 'Current', 'Account']
# ['Can', 'EEFC', 'Account', 'opened', 'Special', 'Economic', 'Zone', '(', 'SEZ', ')', 'Units']
# ['What', 'I', 'case', 'I', 'unable', 'access', 'Company', "'s", 'Current', 'Account']
# ['What', 'transactions', 'included', 'part', 'free', 'inter-city', 'clearing', 'limit']
# ['How', 'M', '&', 'N', 'Bank', 'Premium', 'CA', 'different', 'regular', 'CA', 'offered', 'banks']
# ['Must', 'I', 'open', 'Premium', 'Current', 'account', 'location', 'I', 'company', 'office']
# ['Can', 'I', 'access', 'Premium', 'Current', 'Account', 'M', '&', 'N', 'Bank', 'branch']
# ['With', 'Premium', 'Current', 'Account', 'I', 'make', 'payments', 'suppliers', 'M', '&', 'N', 'Bank', 'Branches', 'Single', 'Cheque', 'Book']
# ['Can', 'I', 'access', 'account', 'telephone', 'conduct', 'routine', 'daily', 'transactions']
# ['What', 'included', 'Bulk', 'Transactions']
# ['What', 'documents', 'required', 'opening', 'Current', 'Account', 'partnership', 'firm']
# ['Can', 'I', 'access', 'account', 'telephone', 'conduct', 'routine', 'daily', 'transactions']
# ['How', 'I', 'become', 'eligible', 'M', '&', 'N', 'Bank', 'Regular', 'Current', 'Account']
# ['What', 'documents', 'required', 'opening', 'Current', 'Account', 'partnership', 'firm']
# ['Must', 'I', 'open', 'Regular', 'Current', 'account', 'location', 'I', 'company', 'office']
# ['What', 'initial', 'deposit', 'amount', 'required', 'open', 'Flexi', 'Account']
# ['What', 'I', 'case', 'I', 'unable', 'access', 'Company', "'s", 'Current', 'Account', 'using', 'NetBanking']
# ['Can', 'I', 'access', 'account', 'telephone', 'conduct', 'routine', 'daily', 'transactions']
# ['How', 'Flexi', 'Current', 'account', 'different', 'regular', 'current', 'account']
# ['What', 'documents', 'required', 'opening', 'Current', 'Account', 'partnership', 'firm']
# ['What', 'transactions', 'included', 'part', 'Free', 'Anywhere', 'Transactions', 'limit', 'month']
# ['How', 'much', 'cash', 'I', 'deposit', 'per', 'month', 'home', 'branch', ',', 'without', 'charged']
# ['Can', 'I', 'access', 'account', 'M', '&', 'N', 'Bank', 'branch']
# ['What', 'minimum', 'balance', 'I', 'need', 'maintain', 'Flexi', 'Current', 'Account']
# ['What', 'minimum', 'balance', 'required', 'Apex', 'Current', 'account']
# ['Can', 'I', 'access', 'account', 'M', '&', 'N', 'Bank', 'branch']
# ['Is', 'necessary', 'open', 'Apex', 'Current', 'Account', 'location', 'company', 'office']
# ['Can', 'I', 'make', 'payments', 'suppliers', 'M', '&', 'N', 'Bank', 'branches', 'single', 'cheque', 'book']
# ['What', 'documents', 'required', 'opening', 'Current', 'Account', 'partnership', 'firm']
# ['Can', 'I', 'access', 'account', 'telephone', 'conduct', 'routine', 'daily', 'transactions']
# ['What', 'I', 'case', 'I', 'unable', 'access', 'Company', "'s", 'Current', 'Account', 'Net', 'Banking']
# ['How', 'Apex', 'Current', 'account', 'different', 'regular', 'Current', 'Account']
# ['What', 'transactions', 'included', 'part', 'Free', 'Anywhere', 'Transactions', 'limit', 'month']
# ['What', 'transactions', 'included', 'part', 'Free', 'Anywhere', 'Transactions', 'limit', 'month']
# ['Can', 'I', 'make', 'payments', 'suppliers', 'M', '&', 'N', 'Bank', 'branches', 'single', 'cheque', 'book']
# ['What', 'I', 'case', 'I', 'unable', 'access', 'Company', "'s", 'Current', 'Account', 'Net', 'Banking']
# ['Is', 'necessary', 'open', 'Max', 'Current', 'Account', 'location', 'company', 'office']
# ['Can', 'I', 'access', 'account', 'telephone', 'conduct', 'routine', 'daily', 'transactions']
# ['What', 'documents', 'required', 'opening', 'Current', 'Account', 'partnership', 'firm']
# ['What', 'initial', 'deposit', 'amount', 'required', 'open', 'Max', 'Current', 'account']
# ['What', 'minimum', 'balance', 'I', 'need', 'maintain', 'Max', 'Current', 'Account']
# ['Can', 'I', 'access', 'account', 'M', '&', 'N', 'Bank', 'branch']
# ['How', 'M', '&', 'N', 'Bank', "'s", 'Max', 'Current', 'account', 'different', 'regular', 'Current', 'Account']
# ['Must', 'I', 'open', 'account', 'location', 'I', 'company', 'office']
# ['What', 'minimum', 'Average', 'Monthly', 'Balance', 'required', 'I', 'Merchant', 'Advantage', 'Current', 'Account']
# ['What', 'documents', 'required', 'opening', 'Current', 'Account', 'partnership', 'firm']
# ['Must', 'I', 'open', 'Merchant', 'Advantage', 'Current', 'Account', 'location', 'I', 'company', 'office']
# ['Can', 'I', 'access', 'account', 'telephone', 'conduct', 'routine', 'daily', 'transactions']
# ['Can', 'I', 'access', 'Merchant', 'Advantage', 'Plus', 'Current', 'Account', 'M', '&', 'N', 'Bank', 'branch']
# ['With', 'Merchant', 'Plus', 'Current', 'Account', 'I', 'make', 'payments', 'suppliers', 'M', '&', 'N', 'Bank', 'Branches', 'Single', 'Cheque', 'Book']
# ['What', 'documents', 'required', 'opening', 'Current', 'Account', 'partnership', 'firm']
# ['Can', 'I', 'access', 'account', 'telephone', 'conduct', 'routine', 'daily', 'transactions']
# ['How', 'Merchant', 'Advantage', 'Plus', 'Current', 'Account', 'different', 'Regular', 'Current', 'Account', 'offered', 'banks']
# ['How', 'Merchant', 'Advantage', 'Plus', 'Current', 'Account', 'different', 'Regular', 'Current', 'Account', 'offered', 'banks']
# ['What', 'minimum', 'Average', 'Monthly', 'Balance', 'I', 'maintain', 'Merchant', 'Advantage', 'Plus', 'Current', 'Account']
# ['What', 'documents', 'required', 'opening', 'Current', 'Account', 'partnership', 'firm']
# ['What', 'documents', 'required', 'opening', 'Current', 'Account', 'partnership', 'firm']
# ['Can', 'I', 'access', 'account', 'M', '&', 'N', 'Bank', 'branch']
# ['Can', 'I', 'make', 'payments', 'suppliers', 'M', '&', 'N', 'Bank', 'branches', 'single', 'cheque', 'book']
# ['Is', 'necessary', 'open', 'Ultima', 'Current', 'Account', 'location', 'company', 'office']
# ['Can', 'I', 'access', 'account', 'telephone', 'conduct', 'routine', 'daily', 'transactions']
# ['How', 'Ultima', 'Current', 'account', 'different', 'Regular', 'Current', 'Account']
# ['What', 'minimum', 'balance', 'required', 'Ultima', 'Current', 'account']
# ['What', 'transactions', 'included', 'part', 'Free', 'Anywhere', 'Transactions', 'limit', 'month']
# ['What', 'I', 'case', 'I', 'unable', 'access', 'Company', "'s", 'Current', 'Account', 'Net', 'Banking']
# ['What', 'minimum', 'docs', 'required', 'open', 'Institutional', 'current', 'account']
# ['How', 'Institutional', 'Current', 'Account', 'different', 'Regular', 'Current', 'Account']
# ['What', 'I', 'case', 'I', 'unable', 'access', 'Institutional', 'Current', 'Account', 'Net', 'Banking']
# ['Can', 'I', 'access', 'account', 'M', '&', 'N', 'Bank', 'branch']
# ['Must', 'I', 'open', 'Institutional', 'Current', 'Account', 'location', 'I', 'company', 'office']
# ['What', 'minimum', 'balance', 'required', 'Institutional', 'Current', 'Account']
# ['How', 'I', 'become', 'eligible', 'M', '&', 'N', 'Bank', 'Institutional', 'Current', 'Account']
# ['Can', 'I', 'access', 'account', 'telephone', 'conduct', 'routine', 'daily', 'transactions']
# ['Is', 'necessary', 'open', 'Institutional', 'Current', 'Account', 'location', 'company', 'office']
# ['What', 'transactions', 'included', 'part', 'Free', 'Anywhere', 'Transactions', 'limit', 'month']
# ['Can', 'I', 'make', 'payments', 'suppliers', 'M', '&', 'N', 'Bank', 'branches', 'single', 'cheque', 'book']
# ['What', 'permissible', 'Debits', 'RFC', 'Domestic', 'Account']
# ['Can', 'I', 'access', 'account', 'telephone', 'conduct', 'routine', 'daily', 'transactions']
# ['Who', 'open', 'RFC', 'Domestic', 'Account']
# ['What', 'documents', 'required', 'opening', 'Current', 'Account', 'partnership', 'firm']
# ['What', 'permissible', 'credits', 'RFC', 'Domestic', 'Account']
# ['In', 'currencies', 'I', 'open', 'RFC', 'Domestic', 'account']
# ['Whether', 'EEFC', 'balances', 'covered', 'exchange', 'risk']
# ['Is', 'restriction', 'withdrawal', 'rupees', 'funds', 'held', 'EEFC', 'account']
# ['How', 'much', 'foreign', 'exchange', 'earnings', 'credited', 'EEFC', 'account']
# ['What', 'permissible', 'credits', 'EEFC', 'account']
# ['What', 'permissible', 'debits', 'account']
# ['What', 'benefits', 'Smartup', 'Solutions']
# ['What', 'offer', 'Salary', 'Account', 'Smartup', 'programme']
# ['If', 'I', 'query', ',', 'I', 'need', 'visit', 'branch']
# ['What', 'key', 'features', 'CMS', 'eCMS', 'M', '&', 'N', 'bank']
# ['What', 'Collection', 'Solutions', 'available']
# ['What', 'key', 'features', 'current', 'account']
# ['What', 'key', 'features', 'Payment', 'gateway', 'M', '&', 'N', 'bank']
# ['What', 'benefits', 'Payzapp', 'business']
# ['Who', 'open', 'SmartUp', 'Current', 'Account']
# ['What', 'Smartup', 'Solutions']
# ['What', 'Payment', 'Solutions', 'available']
# ['I', 'existing', 'bank', 'account', 'Bank', '.', 'Can', 'I', 'still', 'open', 'SmartUp', 'Current', 'Account']
# ['I', 'technology', 'Start-up', '.', 'Can', 'I', 'still', 'open', 'SmartUp', 'Current', 'Account']
# ['Do', 'I', 'get', 'access', 'services', 'offered', 'Smartup', 'programme', 'I', 'start', 'banking', 'M', '&', 'N', 'BANK']
# ['Do', 'I', 'need', 'pay', 'penalty', 'premature', 'closure', 'Fixed', 'Deposits']
# ['Where', 'I', 'get', 'Fixed', 'Deposit', 'advice']
# ['Why', 'principal', 'amount', 'fixed', 'deposit', 'maturity', 'amount', 'Fixed', 'Deposit']
# ['Does', 'M', '&', 'N', 'Bank', 'offer', 'preferential', 'rate', 'interest', 'Fixed', 'Deposits', 'Senior', 'Citizens']
# ['Where', 'I', 'register', 'M', '&', 'N', 'Banks', 'NetBanking', 'facility']
# ['How', 'I', 'book', 'Fixed', 'Deposit', 'NetBanking']
# ['I', 'made', 'Fixed', 'Deposit', 'M', '&', 'N', 'Bank', '.', 'I', 'want', 'update', 'PAN', 'details', 'account', ',', 'I', 'update', 'new', 'PAN', 'details']
# ['What', 'time', 'taken', 'realize', 'outstation', 'cheques']
# ['Whom', 'I', 'approach', 'service', 'related', 'M', '&', 'N', 'Bank', 'Fixed', 'Deposits']
# ['How', 'I', 'avail', 'exemption', 'TDS', 'interest', 'earned', 'Fixed', 'Deposits']
# ['How', 'I', 'prematurely', 'liquidate', 'Fixed', 'Deposits']
# ['How', 'Download', 'TDS', 'Certificate', 'Online']
# ['How', 'change', 'existing', 'fixed', 'deposit', 'account', 'tenure']
# ['How', 'TDS', 'deducted']
# ['Can', 'TDS', 'recovered', 'principle', 'FD']
# ['When', 'Bank', 'issue', 'TDS', 'Certificate']
# ['Can', 'TDS', 'influence', 'maturity', 'deposit']
# ['What', 'implications', 'booking', 'FD', 'without', 'PAN']
# ['Will', 'changes', 'deposit', 'portfolio', 'affect', 'TDS', 'liability']
# ['When', 'TDS', 'deducted', 'Regular', 'Fixed', 'Deposit']
# ['What', 'documents', 'required', 'open', 'senior', 'citizen', 'Regular', 'Fixed', 'Deposit']
# ['Can', 'I', 'open', 'joint', 'account', 'non-senior', 'citizen', 'Regular', 'Fixed', 'Deposit']
# ['As', 'Regular', 'Fixed', 'Deposit', 'holder', ',', 'How', 'I', 'apply', 'exemption', 'TDS']
# ['How', 'prematurely', 'liquidate', 'Fixed', 'Deposit', 'Online']
# ['What', 'new', 'policy', 'regards', 'PAN', 'book', 'fixed', 'deposit', 'bank']
# ['When', 'I', 'become', 'liable', 'TDS']
# ['What', 'documents', 'required', 'open', 'senior', 'citizen', '5', 'Year', 'Tax', 'Saving', 'Fixed', 'Deposit']
# ['Will', 'bank', 'issue', 'TDS', 'certificate']
# ['As', '5', 'Year', 'Tax', 'Saving', 'Fixed', 'Deposit', 'holder', ',', 'How', 'I', 'apply', 'exemption', 'TDS']
# ['When', 'TDS', 'deducted', '5', 'Year', 'Tax', 'Saving', 'Fixed', 'Deposit']
# ['Does', 'change', 'enhancement', 'deposit', 'portfolio', 'affect', 'TDS', 'liability']
# ['Do', 'I', 'need', 'visit', 'branch', 'receive', '5', 'Year', 'Tax', 'Saving', 'Fixed', 'Deposit', 'proceeds', 'maturity']
# ['Can', 'I', 'open', 'joint', 'account', 'non-senior', 'citizen', '5', 'Year', 'Tax', 'Saving', 'Fixed', 'Deposit']
# ['How', 'apply', '5', 'Year', 'Tax', 'Saving', 'Fixed', 'Deposit']
# ['When', 'I', 'liable', 'TDS', '(', 'Tax', 'Deduction', 'Source', ')']
# ['If', 'I', 'joint', 'Super', 'Saver', 'Account', ',', 'account', 'holders', 'get', 'ATM/Debit', 'card']
# ['Is', 'Super', 'Saver', 'Account', 'normal', 'Savings', 'Account']
# ['What', 'documents', 'required', 'open', 'senior', 'citizen', 'Super', 'Saver', 'Facility']
# ['I', 'part', 'Trust', 'I', 'open', 'Super', 'Saver', 'Account']
# ['Can', 'I', 'add', 'Fixed', 'Deposit']
# ['Will', 'TDS', 'charged', 'gross', 'interest', 'earned', 'net', 'interest', 'earned']
# ['Can', 'I', 'Super', 'Saver', 'Facility', 'Sweep-in', 'Facility', 'one', 'Fixed', 'Deposit']
# ['Can', 'I', 'Super', 'Saver', 'Facility', 'Sweep-in', 'Facility', 'Savings', 'Account']
# ['How', 'I', 'apply', 'Super', 'Saver', 'Account']
# ['Can', 'joint', 'account', 'opened', 'non-senior', 'citizen']
# ['How', 'work']
# ['Can', 'I', 'get', 'overdraft', 'facility', 'fixed', 'deposit', 'funds']
# ['What', 'benefits']
# ['How', 'I', 'apply', 'Sweep-in', 'facility']
# ['Can', 'I', 'Super', 'Saver', 'facility', 'Sweep-In', 'facility', 'Fixed', 'Deposit']
# ['Will', 'principal', 'interest', 'amount', 'Fixed', 'Deposit', 'considered']
# ['Can', 'I', 'Super', 'saver', 'facility', 'Sweep-in', 'facility', 'Savings', 'Account']
# ['On', 'basis', 'Sweep-in', 'facility', 'gets', 'triggered']
# ['Can', 'Fixed', 'Deposit', 'linked', 'two', 'different', 'Savings', 'Accounts', 'Sweep-in']
# ['Can', 'Sweep-in', 'facility', 'multiple', 'deposits']
# ['Can', 'I', 'link', 'accounts', 'held', 'different', 'account', 'titles', 'Savings', 'Account', 'Sweep-In', 'facility']
# ['What', 'Sweep-in', 'facility']
# ['Is', 'nomination', 'facility']
# ['Is', 'monthly', 'quarterly', 'interest', 'pay-out', 'option']
# ['Can', 'I', 'change', 'tenure', 'installment', 'due', 'date', ',', '(', 'auto', 'debit', 'date', ')', 'Recurring', 'Deposit']
# ['For', 'period', 'I', 'open', 'Recurring', 'Deposit']
# ['Can', 'I', 'choose', 'instalment', 'date']
# ['Can', 'partial', 'Payments', 'made', 'Recurring', 'Deposits']
# ['What', 'maximum', 'deposit', 'amount', 'Recurring', 'Deposit', 'account', 'opened']
# ['What', 'certain', 'RD', 'installments', 'paid']
# ['How', 'Recurring', 'Deposits', 'work']
# ['Can', 'I', 'pay', 'one', 'instalment', 'time']
# ['How', 'Interest', 'Rate', 'calculated', 'premature', 'withdrawal', 'Recurring', 'Deposit']
# ['Is', 'overdraft', 'facility', 'allowed']
# ['How', 'I', 'prematurely', 'liquidate', 'recurring', 'deposit']
# ['What', 'happens', 'I', "n't", 'pay', 'instalment']
# ['Can', 'Recurring', 'Deposit', 'opened', 'joint', 'names']
# ['Can', 'first', 'applicant', 'Recurring', 'Deposit', 'minor']
# ['Can', 'I', 'withdraw', 'prematurely', 'Recurring', 'Deposit']
# ['I', "'m", 'senior', 'citizen', 'extra', 'benefits']
# ['How', 'open', 'Recurring', 'Deposit']
# ['Can', 'covert', 'existing', 'saving', 'account', 'pension', 'account']
# ['Any', 'minimum', 'Balance', 'need', 'maintained', 'account']
# ['When', 'open', 'pension', 'accounts']
# ['Is', 'nomination', 'required', 'account']
# ['Can', 'pension', 'account', 'opened', 'jointly']
# ['What', 'charges', 'collection', 'outstation', 'cheques']
# ['What', 'time', 'taken', 'realize', 'outstation', 'cheques']
# ['How', 'I', 'know', 'beneficiary', "'s", 'details', 'cheque', 'issued', 'name', '(', 'Basic', 'Savings', 'Bank', 'Deposit', 'Account', '-', 'Farmers', ')']
# ['How', 'I', 'get', 'International', 'Debit', 'Card', 'Basic', 'Savings', 'Bank', 'Deposit', 'Account', '-', 'Farmers']
# ['What', 'I', 'NEFT', 'facility']
# ['Are', 'IVR', 'based', 'calls', 'free']
# ['How', 'I', 'apply', 'Basic', 'Savings', 'Bank', 'Deposit', 'Account', '-', 'Farmers', 'M', '&', 'N', 'Bank']
# ['How', 'I', 'know', 'beneficiary', "'s", 'details', 'cheque', 'issued', 'name', '(', 'Kisan', 'Club', 'Savings', 'account', ')']
# ['Is', 'nomination', 'facility', 'available', 'lockers']
# ['What', 'timings', 'locker', 'operations']
# ['How', 'many', 'nominees', 'added', 'single', 'locker']
# ['Can', 'I', 'pay', 'rent', 'locker', 'account']
# ['What', 'procedure', 'add', '/', 'cancel', '/', 'modify', 'nominee', 'locker']
# ['What', 'tenure', 'options']
# ['When', 'I', 'open', 'salary', 'account', 'M', '&', 'N', 'Bank']
# ['I', 'received', 'Welcome', 'Letter', 'ATM/Debit', 'Card', 'PIN', 'new', 'account']
# ['What', 'time', 'taken', 'realize', 'outstation', 'cheques']
# ['What', 'Account', 'becomes', 'dormant']
# ['What', 'documents', 'required', 'open', 'salary', 'account']
# ['Can', 'salary', 'account', 'joint', 'applicant']
# ['Is', 'employment', 'confirmation', 'mandatory', 'open', 'Classic', 'Salary', 'Account']
# ['What', 'time', 'taken', 'realize', 'outstation', 'cheques']
# ['How', 'I', 'stop', 'cheque', 'payment']
# ['Can', 'Company', 'ID', 'card', 'accepted', 'Photo', 'ID', 'document']
# ['What', 'procedure', 'add/modify', 'delete', 'nominee', 'accounts', 'deposits']
# ['How', 'long', 'take', 'update', 'change', 'address']
# ['Can', 'I', 'use', 'existing', 'Salary', 'Account', 'I', 'changed', 'employers']
# ['How', 'I', 'know', 'beneficiary', "'s", 'details', 'cheque', 'issued', 'name']
# ['From', 'I', 'enquire', 'status', 'request', 'change', 'residential', 'address', 'M', '&', 'N', 'Bank', 'account']
# ['From', 'I', 'enquire', 'status', 'request', 'change', 'residential', 'address', 'M', '&', 'N', 'Bank', 'account']
# ['How', 'I', 'know', 'beneficiary', "'s", 'details', 'cheque', 'issued', 'name']
# ['Can', 'I', 'use', 'existing', 'Salary', 'Account', 'I', 'changed', 'employers']
# ['Is', 'employment', 'confirmation', 'mandatory', 'open', 'Regular', 'Salary', 'Account']
# ['How', 'I', 'stop', 'cheque', 'payment']
# ['What', 'eligibility', 'criteria', 'Personal', 'Accident', 'Death', 'Cover']
# ['What', 'procedure', 'add/modify', 'delete', 'nominee', 'accounts', 'deposits']
# ['How', 'long', 'take', 'update', 'change', 'address']
# ['What', 'time', 'taken', 'realize', 'outstation', 'cheques']
# ['Can', 'Company', 'ID', 'card', 'accepted', 'Photo', 'ID', 'document']
# ['Can', 'I', 'use', 'existing', 'Salary', 'Account', 'I', 'changed', 'employers']
# ['Can', 'salary', 'account', 'joint', 'applicant']
# ['What', 'time', 'taken', 'realize', 'outstation', 'cheques']
# ['How', 'long', 'take', 'update', 'change', 'address']
# ['Is', 'employment', 'confirmation', 'mandatory', 'open', 'Premium', 'Salary', 'Account']
# ['What', 'eligibility', 'criteria', 'Personal', 'Accident', 'Death', 'Cover']
# ['How', 'I', 'stop', 'cheque', 'payment']
# ['Can', 'Company', 'ID', 'card', 'accepted', 'Photo', 'ID', 'document']
# ['How', 'I', 'know', 'beneficiary', "'s", 'details', 'cheque', 'issued', 'name']
# ['From', 'I', 'enquire', 'status', 'request', 'change', 'residential', 'address', 'M', '&', 'N', 'Bank', 'account']
# ['What', 'modes', 'accident', 'covered', 'Personal', 'Accidental', 'Death', 'Cover']
# ['How', 'I', 'know', 'beneficiary', "'s", 'details', 'cheque', 'issued', 'name']
# ['From', 'I', 'enquire', 'status', 'request', 'change', 'residential', 'address', 'M', '&', 'N', 'Bank', 'account']
# ['Is', 'employment', 'confirmation', 'mandatory', 'open', 'Defence', 'Salary', 'Account']
# ['What', 'eligibility', 'criteria', 'Personal', 'Accident', 'Death', 'Cover']
# ['What', 'procedure', 'add/modify', 'delete', 'nominee', 'accounts', 'deposits']
# ['Can', 'Defence', 'ID', 'card', 'accepted', 'Photo', 'ID', 'document', '(', 'Defense', 'Salary', 'Account', ')']
# ['How', 'long', 'take', 'update', 'change', 'address']
# ['What', 'time', 'taken', 'realize', 'outstation', 'cheques']
# ['How', 'I', 'stop', 'cheque', 'payment']
# ['Can', 'I', 'use', 'existing', 'Salary', 'Account', 'I', 'changed', 'employers']
# ['Can', 'Company', 'ID', 'card', 'accepted', 'Photo', 'ID', 'document', '(', 'Basic', 'Savings', 'Bank', 'Deposit', 'Account', '-', 'Salary', ')']
# ['Is', 'address', 'proof', 'mandatory', 'requirement', '(', 'Basic', 'Savings', 'Bank', 'Deposit', 'Account', '-', 'Salary', ')']
# ['How', 'I', 'stop', 'cheque', 'payment']
# ['Can', 'I', 'use', 'existing', 'Basic', 'Savings', 'Bank', 'Deposit', 'Account', '-', 'Salary', 'I', 'changed', 'employers']
# ['What', 'time', 'taken', 'realize', 'outstation', 'cheques']
# ['Is', 'employment', 'confirmation', 'mandatory', 'open', 'Basic', 'Savings', 'Bank', 'Deposit', 'Account', '-', 'Salary']
# ['What', 'procedure', 'add/modify', 'delete', 'nominee', 'accounts', 'deposits']
# ['How', 'long', 'take', 'update', 'change', 'address']
# ['How', 'I', 'know', 'beneficiary', "'s", 'details', 'cheque', 'issued', 'name']
# ['From', 'I', 'enquire', 'status', 'request', 'change', 'residential', 'address', 'M', '&', 'N', 'Bank', 'account']
# ['How', 'I', 'know', 'beneficiary', "'s", 'details', 'cheque', 'issued', 'name']
# ['From', 'I', 'enquire', 'status', 'request', 'change', 'residential', 'address', 'M', '&', 'N', 'Bank', 'account']
# ['What', 'procedure', 'add/modify', 'delete', 'nominee', 'accounts', 'deposits']
# ['What', 'I', 'need', 'open', 'joint', 'account']
# ['Will', 'I', 'able', 'access', 'accounts', 'establishments/ATMs', 'single', 'Debit', 'Card']
# ['Will', 'I', 'earn', 'interest', 'Reimbursement', 'Account']
# ['Why', 'I', 'need', 'Reimbursement', 'Account']
# ['Will', 'I', 'entitled', 'kind', 'benefits', 'account', 'Salary', 'account']
# ['What', 'time', 'taken', 'realize', 'outstation', 'cheques']
# ['How', 'long', 'take', 'update', 'change', 'address']
# ['How', 'I', 'stop', 'cheque', 'payment']
# ['Can', 'I', 'use', 'account', 'regular', 'cheque/', 'cash', 'deposits', '&', 'withdrawals']
# ['Can', 'I', 'multiple', 'Zero', 'Balance', 'Salary', 'Account', 'Bank']
# ['What', 'rate', 'interest', 'I', 'earn', 'balance', 'Savings', 'Account']
# ['What', 'happens', 'I', "n't", 'use', 'savings', 'account', 'long', 'time']
# ['How', 'I', 'register', 'Email', 'Statement/s']
# ['How', 'I', 'change', '/', 'add', 'email', 'ID', 'account']
# ['How', 'I', 'update', 'PAN', 'number']
# ['What', 'time', 'taken', 'realize', 'outstation', 'cheques']
# ['How', 'I', 'request', 'Physical', 'Statement/s']
# ['Reissuance', 'ATM/Debit', 'Card', 'PIN']
# ['How', 'I', 'change', '/', 'update', 'address', 'account']
# ['How', 'I', 'activate', "'Dormant", "'", 'Savings', 'Account']
# ['How', 'Do', 'I', 'Change', '/', 'Add', 'Mobile', 'Number']
# ['How', 'transfer', 'Savings', 'Account', 'one', 'branch', 'another']
# ['What', 'documents', 'required', 'open', 'New', 'Savings', 'Account']
# ['What', 'frequency', 'interest', 'payout', 'Savings', 'Account']
# ['Can', 'I', 'get', 'Debit', 'Card', 'linked', 'Institutional', 'Savings', 'Account']
# ['What', 'general', 'documentation', 'requirement', 'open', 'Institutional', 'Savings', 'Account']
# ['Can', 'unregistered', 'institutions', 'open', 'Institutional', 'Savings', 'Account']
# ['Can', 'transactions', 'done', 'M', '&', 'N', 'Bank', 'branches']
# ['My', 'institution', 'start', 'receiving', 'foreign', 'contribution', '.', 'Can', 'I', 'receive', 'Institutional', 'Savings', 'Account']
# ['Can', 'funds', 'credited', 'FCRA', 'account', 'simply', 'account', 'opened']
# ['Is', 'AMB', '(', 'Average', 'Monthly', 'Balance', ')', 'declaration', 'required', 'submitted', 'along', 'documents', 'Institutional', 'Savings', 'Account']
# ['Can', 'NetBanking', 'facility', '(', 'financial', 'rights', ')', 'enjoyed', 'authorized', 'signatories', 'Institutional', 'Savings', 'Account']
# ['What', 'AMB', '(', 'Average', 'Monthly', 'Balance', ')', 'requirement', 'Institutional', 'Savings', 'Account']
# ['Do', 'I', 'need', 'close', 'account', 'kid', 'attains', 'majority']
# ['How', 'long', 'Standing', 'Instruction', 'given', 'valid']
# ['Is', 'primary', 'Customer', 'ID', 'Kids', 'Advantage', 'account', 'Customer', 'ID']
# ['What', 'documents', 'required', 'open', 'Women', "'s", 'Savings', 'Account']
# ['What', 'procedure', 'follow', 'Debit', 'Card', 'PIN', 'blocked']
# ['Why', '2nd', 'Level', 'authentication', 'made', 'mandatory', 'Card', 'related', 'online', 'transactions']
# ['Can', 'I', 'use', 'Debit', 'Card', 'pay', 'online']
# ['What', 'I', 'Debit', 'Card', 'working']
# ['How', 'I', 'enable', 'International', 'Usage', 'M', '&', 'N', 'Bank', 'Rewards', 'Debit', 'Card']
# ['What', 'Debit', 'Card', 'transaction', 'fees', 'I', 'swipe', 'card', 'Petrol', 'pumps', 'Railway', 'stations']
# ['What', 'procedure', 'replace', 'damaged', 'Debit', 'Card']
# ['Why', 'customer', 'required', 'fill', 'cardholder', 'dispute', 'form', '(', 'CDF', ')', 'report', 'transaction', 'dispute']
# ['What', 'time', 'frame', 'resolve', 'Domestic', 'ATM', 'transaction', 'disputes']
# ['What', 'time', 'frame', 'report', 'Debit', 'Card', 'transaction', 'dispute']
# ['Which', 'documents', 'submitted', 'respect', 'failed/', 'disputed', 'transaction']
# ['How', 'I', 'report', 'service/merchant', 'related', 'transaction', 'dispute', 'incurred', 'using', 'Debit', 'Card', 'transaction']
# ['What', 'service', 'dispute']
# ['What', 'time', 'frame', 'resolve', 'Purchase/', 'Online', '&', 'International', 'ATM', 'transaction', 'disputes']
# ['Are', 'charges', 'I', 'know', 'Imperia', 'Platinum', 'Chip', 'Debit', 'Card']
# ['What', 'I', 'case', 'void', 'transaction', 'Imperia', 'Platinum', 'Chip', 'Debit', 'Card']
# ['Where', 'I', 'use', 'EasyShop', 'Platinum', 'Debit', 'Card']
# ['Are', 'transaction', 'limits', 'Imperia', 'Platinum', 'Chip', 'Debit', 'Card']
# ['What', 'I', 'case', 'void', 'transaction', 'Platinum', 'Debit', 'Card']
# ['Where', 'I', 'use', 'EasyShop', 'Platinum', 'Debit', 'Card']
# ['Are', 'transaction', 'limits', 'Platinum', 'Debit', 'Card']
# ['Are', 'charges', 'I', 'know', 'Platinum', 'Debit', 'Card']
# ['What', 'I', 'case', 'void', 'transaction', 'Titanium', 'Royale', 'Debit', 'Card']
# ['Where', 'I', 'use', 'EasyShop', 'Titanium', 'Royale', 'Debit', 'Card']
# ['Are', 'charges', 'I', 'know', 'Titanium', 'Royale', 'Debit', 'Card']
# ['Are', 'transaction', 'limits', 'Titanium', 'Royale', 'Debit', 'Card']
# ['What', 'I', 'case', 'void', 'transaction', 'Gold', 'Debit', 'Card']
# ['How', 'I', 'claim', 'Personal', 'Accident', 'Death', 'Cover', 'Gold', 'Debit', 'Card']
# ['Where', 'I', 'use', 'EasyShop', 'Gold', 'Debit', 'Card']
# ['Are', 'extra', 'charges', 'Gold', 'Debit', 'Card']
# ['Are', 'transaction', 'limits', 'Gold', 'Debit', 'Card']
# ['Where', 'I', 'use', 'EasyShop', 'Titanium', 'Debit', 'Card']
# ['Are', 'charges', 'aware', 'Titanium', 'Debit', 'Card']
# ['What', 'transaction', 'limits', 'Titanium', 'Debit', 'Card']
# ['What', 'I', 'case', 'void', 'transaction', 'Titanium', 'Debit', 'Card']
# ['What', 'I', 'case', 'void', 'transaction']
# ['What', 'I', 'case', 'void', 'transaction', 'International', 'Debit', 'Card']
# ['Are', 'charges', 'I', 'know', 'International', 'Debit', 'Card']
# ['Where', 'I', 'use', 'EasyShop', 'International', 'Debit', 'Card']
# ['Are', 'transaction', 'limits', 'Debit', 'Card']
# ['Are', 'extra', 'charges', 'International', 'Business', 'Debit', 'Card']
# ['Where', 'I', 'use', 'EasyShop', 'Business', 'Debit', 'Card']
# ['What', 'I', 'case', 'void', 'transaction', 'International', 'Business', 'Debit', 'Card']
# ['Are', 'transaction', 'limits', 'Business', 'Debit', 'Card']
# ['What', 'I', 'case', 'void', 'transaction', 'Womans', 'Advantage', 'Debit', 'Card']
# ['Where', 'I', 'use', 'EasyShop', 'Womans', 'Advantage', 'Debit', 'Card']
# ['Are', 'extra', 'charges', 'Womans', 'Advantage', 'Debit', 'Card']
# ['What', 'Womans', 'Advantage', 'Debit', 'Card', 'lost', 'stolen']
# ['Are', 'transaction', 'limits', 'Womans', 'Advantage', 'Debit', 'Card']
# ['Are', 'extra', 'charges', 'NRO', 'Debit', 'Card']
# ['Where', 'I', 'use', 'EasyShop', 'NRO', 'Debit', 'Card']
# ['What', 'I', 'case', 'void', 'transaction', 'NRO', 'Debit', 'Card']
# ['Are', 'transaction', 'limits', 'NRO', 'Debit', 'Card']
# ['Can', 'JetPrivilege', 'M', '&', 'N', 'Bank', 'World', 'Debit', 'Card', 'taken', 'public', '/', 'private', '/', 'partnership', 'firm']
# ['How', 'I', 'earn', 'JPMiles', 'JetPrivilege', 'M', '&', 'N', 'Bank', 'World', 'Card']
# ['When', 'I', 'get', 'Enrollment', 'Benefits', 'JetPrivilege', 'M', '&', 'N', 'Bank', 'World', 'Debit', 'Card']
# ['Can', 'chip', 'card', 'used', 'online', 'transactions']
# ['Will', 'RM.750', 'discount', 'voucher', 'applicable', 'booking', 'done', 'jetairways.com']
# ['What', 'I', 'want', 'use', 'Debit', 'Card', 'internationally']
# ['Can', 'I', 'use', 'RuPay', 'Platinum', 'Debit', 'Card', 'pay', 'online']
# ['Where', 'RuPay', 'Platinum', 'Debit', 'Card', 'used']
# ['Can', 'I', 'use', 'RuPay', 'ATM', 'card', 'Merchant', 'outlets', 'Ecom', 'website']
# ['What', 'I', 'case', 'void', 'transaction', 'Rewards', 'Debit', 'Card']
# ['What', 'transaction', 'limits', 'Rewards', 'Debit', 'Card']
# ['Are', 'charges', 'I', 'know', 'M', '&', 'N', 'Bank', 'Rewards', 'Debit', 'Card']
# ['Can', 'chip', 'card', 'used', 'online', 'transactions']
# ['What', 'Times', 'Points']
# ['Where', 'I', 'contact', 'write', 'know', 'existing', 'offers', 'cards']
# ['Where', 'I', 'contact', 'write', 'doubts', 'queries']
# ['How', 'Can', 'I', 'get', 'Times', 'Points', 'Debit', 'Card']
# ['Except', 'digital', 'media', 'consumption', ',', 'medium', 'earning', 'Times', 'Points']
# ['If', 'I', 'hotlist', 'card', ',', 'I', 'get', 'deregister', 'Times', 'points', 'program']
# ['How', 'I', 'reset', 'password']
# ['Why', 'Should', 'I', 'take', 'card']
# ['How', 'much', 'Times', 'points', 'I', 'earn', 'activity', 'TIL']
# ['Where', 'I', 'burn', 'accumulated', 'Times', 'points']
# ['When', 'I', 'get', 'enrollment', 'Times', 'points']
# ['How', 'long', 'I', 'keep', 'earned', 'Times', 'points']
# ['What', 'Terms', 'Conditions', 'offers', 'disposal']
# ['What', 'validity', 'offers']
# ['I', 'already', 'member', 'Times', 'points', ',', 'I', 'need', 'register']
# ['Which', 'Times', 'group', 'digital', 'properties', 'offer', 'times', 'points']
# ['Does', 'customer', 'need', 'log-in', 'every', 'Times', 'Internet', 'Limited', 'page', 'earning', 'Times', 'Points']
# ['Where', 'I', 'check', 'Times', 'points', 'earned', 'transactions']
# ['What', 'I', 'I', 'issue', 'related', 'product', 'using', 'Times', 'points', 'portal/link']
# ['How', 'much', 'I', 'going', 'charged', 'yearly', 'Times', 'Points', 'Debit', 'Card']
# ['How', 'I', 'earn', 'Times', 'Points']
# ['If', 'I', 'get', 'new', 'card', '(', 'reissue', ')', ',', 'Times', 'point', 'carry', 'forward']
# ['What', 'benefits', 'Times', 'Points', 'Debit', 'Card']
# ['Will', 'I', 'get', 'notification', 'expiry', 'Times', 'points']
# ['I', 'registered', 'times', 'points', 'program', ';', 'I', 'apply', 'Times', 'Point', 'Debit', 'card']
# ['How', 'I', 'register', 'Times', 'Points']
# ['Where', 'I', 'redeem', 'Times', 'Points']
# ['Is', 'Times', 'points', 'Apps', 'I', 'download', 'mobile']
# ['If', 'I', 'two', 'member', 'Id', 'I', 'merge', 'IDs', 'points']
# ['Which', 'offers', 'I', 'eligible', 'Times', 'Debit', 'Card', 'holder']
# ['Do', 'I', 'need', 'mandatorily', 'register']
# ['Is', 'Personal', 'Accidental', 'Death', 'Cover', 'Times', 'Point', 'Debit', 'Card', 'holders']
# ['What', 'I', 'share', 'calling', 'TIL', 'identify']
# ['What', 'I', 'I', 'able', 'avail', 'merchant', 'offers']
# ['Are', 'exclusive', 'benefits', 'come', 'Times', 'Points', 'Debit', 'Card']
# ['I', 'already', 'registered', 'Times', 'Points', 'program', ';', 'happens', 'existing', 'Times', 'Points', 'ID', 'I', 'apply', 'Times', 'point', 'debit', 'card']
# ['What', 'I', 'forget', 'ATM', 'PIN']
# ['How', 'I', 'check', 'balance', 'M', '&', 'N', 'Bank', 'ForexPlus', 'Card']
# ['Who', 'purchase', 'ForexPlus', 'Card']
# ['Can', 'I', 'load', 'ForexPlus', 'card', 'making', 'payment', 'Cash']
# ['How', 'I', 'know', 'ATM', 'accept', 'ForexPlus', 'Card']
# ['What', 'documents', 'I', 'submit', 'I', 'purchase', 'M', '&', 'N', 'Bank', 'ForexPlus', 'card']
# ['How', 'card', 'work']
# ['Can', 'I', 'use', 'DCC/', 'MCC', 'option', 'time', 'transaction']
# ['Do', 'I', 'need', 'pay', 'additional', 'amount', 'Cash', 'withdrawal', 'Charges', 'levied', 'M', '&', 'N', 'Bank', 'ATM', 'transaction']
# ['What', 'currencies', 'available']
# ['Where', 'I', 'get', 'card']
# ['How', 'soon', 'card', 'used', 'purchased']
# ['How', 'I', 'cancel', 'Forex', 'Plus', 'Card']
# ['How', 'I', 'activate', 'e-commerce', 'card']
# ['How', 'I', 'top-up', 'value', 'card', 'I', 'abroad']
# ['Whom', 'I', 'contact', 'card', 'lost', 'stolen']
# ['What', 'M', '&', 'N', 'Bank', 'ForexPlus', 'card']
# ['What', 'maximum', 'value', 'Card', 'used']
# ['I', 'renewed', 'passport', 'new', 'number', '.', 'Do', 'I', 'need', 'update', 'new', 'Passport', 'number', 'ForexPlus', 'Card']
# ['What', 'DCC/', 'MCC', 'stand']
# ['Do', 'I', 'need', 'M', '&', 'N', 'Bank', 'account', 'purchase', 'M', '&', 'N', 'Bank', 'ForexPlus', 'card']
# ['What', 'happens', 'card', 'lost']
# ['How', 'many', 'days', 'advance', 'I', 'purchase', 'foreign', 'exchange']
# ['How', 'much', 'foreign', 'exchange', 'I', 'retain', 'foreign', 'trip']
# ['Can', 'value', 'card', 'topped']
# ['What', 'I', 'Forget', 'Activation', 'Code', '/', 'IPIN']
# ['What', 'maximum', 'value', 'Card', 'used']
# ['How', 'much', 'currency', 'conversion', 'service', 'tax', 'applicable', 'time', 'Load', ',', 'Reload', 'Refund']
# ['What', 'currencies', 'available']
# ['How', 'I', 'know', 'ATM', 'accept', 'ForexPlus', 'Chip', 'Card']
# ['What', 'documents', 'I', 'submit', 'I', 'purchase', 'M', '&', 'N', 'Bank', 'ForexPlus', 'Chip', 'card']
# ['Where', 'I', 'get', 'card']
# ['How', 'soon', 'card', 'used', 'purchased']
# ['I', 'renewed', 'passport', 'new', 'number', '.', 'Do', 'I', 'need', 'update', 'new', 'Passport', 'number', 'ForexPlus', 'Chip', 'Card']
# ['What', 'maximum', 'value', 'Card', 'used']
# ['Are', 'transactions', 'Card', 'used']
# ['Can', 'non', 'Traveller', 'purchase', 'ForexPlus', 'Chip', 'Card']
# ['Can', 'I', 'load', 'ForexPlus', 'Chip', 'card', 'making', 'payment', 'Cash']
# ['Whom', 'I', 'contact', 'card', 'lost', 'stolen']
# ['Can', 'I', 'use', 'DCC/', 'MCC', 'option', 'time', 'transaction']
# ['Can', 'I', 'issue', 'Cheque', 'loading', 'ForexPlus', 'Chip', 'Card']
# ['Can', 'ATM', 'PIN', 'changed']
# ['What', 'M', '&', 'N', 'Bank', 'ForexPlus', 'Chip', 'card']
# ['What', 'I', 'forget', 'ATM', 'PIN']
# ['How', 'I', 'activate', 'e-commerce']
# ['How', 'I', 'cancel', 'ForexPlus', 'Chip', 'Card']
# ['How', 'I', 'top-up', 'value', 'card', 'I', 'abroad']
# ['How', 'I', 'check', 'balance', 'M', '&', 'N', 'Bank', 'ForexPlus', 'Chip', 'Card']
# ['Do', 'I', 'need', 'M', '&', 'N', 'Bank', 'account', 'purchase', 'M', '&', 'N', 'Bank', 'ForexPlus', 'Chip', 'card']
# ['What', 'DCC/', 'MCC', 'stand']
# ['How', 'much', 'foreign', 'exchange', 'I', 'retain', 'foreign', 'trip']
# ['Can', 'value', 'card', 'topped']
# ['Can', 'I', 'use', 'DCC/', 'MCC', 'option', 'time', 'transaction']
# ['What', 'happens', 'card', 'lost']
# ['How', 'I', 'cancel', 'Forex', 'Plus', 'Card']
# ['I', "'m", 'traveller', ',', 'I', 'still', 'benefit', 'ForexPlus', 'Chip', 'Card']
# ['What', 'I', 'Forget', 'Activation', 'Code', '/', 'IPIN']
# ['Can', 'I', 'load', 'ForexPlus', 'Chip', 'Card', 'making', 'payment', 'Cash']
# ['I', 'renewed', 'passport', 'new', 'number', '.', 'Do', 'I', 'need', 'update', 'new', 'Passport', 'number', 'ForexPlus', 'Platinum', 'Card']
# ['What', 'currencies', 'available']
# ['What', 'M', '&', 'N', 'Bank', 'ForexPlus', 'Platinum', '(', 'Chip', ')', 'card']
# ['How', 'I', 'top-up', 'value', 'card', 'I', 'abroad']
# ['What', 'I', 'forget', 'ATM', 'PIN']
# ['Do', 'I', 'need', 'pay', 'additional', 'amount', 'Cash', 'withdrawal', 'Charges', 'levied', 'M', '&', 'N', 'Bank', 'ATM', 'transaction']
# ['How', 'soon', 'card', 'used', 'purchased']
# ['Whom', 'I', 'contact', 'card', 'lost', 'stolen']
# ['What', 'currencies', 'available', 'M', '&', 'N', 'Bank', 'ForexPlus', 'Platinum', 'card']
# ['Do', 'I', 'need', 'M', '&', 'N', 'Bank', 'account', 'purchase', 'M', '&', 'N', 'Bank', 'ForexPlus', 'Platinum', 'card']
# ['What', 'maximum', 'value', 'Card', 'used']
# ['What', 'I', 'need', 'know', 'M', '&', 'N', 'Bank', 'ForexPlus', 'Platinum', 'Card']
# ['Can', 'non-traveller', 'purchase', 'ForexPlus', 'Card']
# ['How', 'I', 'check', 'balance', 'M', '&', 'N', 'Bank', 'ForexPlus', 'Platinum', 'Card']
# ['Whom', 'I', 'contact', 'card', 'lost', 'stolen']
# ['Do', 'I', 'need', 'pay', 'charges', 'availing', 'GCAS']
# ['How', 'I', 'cancel', 'ForexPlus', 'Platinum', 'Card']
# ['How', 'card', 'work']
# ['Are', 'transactions', 'Card', 'used']
# ['Can', 'I', 'issue', 'Cheque', 'loading', 'ForexPlus', 'Platinum', 'Card']
# ['How', 'I', 'activate', 'e-commerce', 'card']
# ['What', 'services', 'I', 'avail', 'GCAS']
# ['Can', 'ATM', 'PIN', 'changed']
# ['Can', 'I', 'use', 'DCC/', 'MCC', 'option', 'time', 'transaction']
# ['How', 'I', 'know', 'ATMs', 'accept', 'M', '&', 'N', 'Bank', 'ForexPlus', 'Platinum', 'Card']
# ['How', 'I', 'avail', 'Global', 'Customer', 'Assistance', 'Services', '(', 'GCAS', ')', 'ForexPlus', 'Platinum', 'Card']
# ['How', 'I', 'know', 'ATM', 'accept', 'ForexPlus', 'Platinum', 'Card']
# ['Can', 'I', 'load', 'Forex', 'card', 'making', 'payment', 'Cash']
# ['What', 'documents', 'I', 'submit', 'I', 'purchase', 'M', '&', 'N', 'Bank', 'ForexPlus', 'Platinum', 'card']
# ['Where', 'I', 'get', 'card']
# ['What', 'happens', 'card', 'lost']
# ['What', 'DCC/', 'MCC', 'stand']
# ['Can', 'I', 'load', 'ForexPlus', 'Platinum', 'card', 'making', 'payment', 'Cash']
# ['Who', 'purchase', 'ForexPlus', 'Platinum', 'Card']
# ['How', 'much', 'foreign', 'exchange', 'I', 'retain', 'foreign', 'trip']
# ['Can', 'value', 'card', 'topped']
# ['How', 'value', 'topped']
# ['How', 'I', 'purchase', 'M', '&', 'N', 'Bank', 'GiftPlus', 'card']
# ['Can', 'I', 'load', 'GiftPlus', 'card', 'making', 'payment', 'Cash']
# ['Can', 'value', 'card', 'topped']
# ['How', 'soon', 'I', 'get', 'GitfPlus', 'card']
# ['Can', 'Gift', 'plus', 'card', 'used', 'outside', 'India']
# ['Is', 'fee', 'levied', 'use', 'card']
# ['How', 'soon', 'I', 'use', 'card', 'I', 'purchased']
# ['What', 'documents', 'I', 'submit', 'I', 'purchase', 'M', '&', 'N', 'Bank', 'Giftplus', 'card']
# ['Is', 'load', 'amount', 'limit']
# ['What', 'charges', 'card']
# ['What', 'I', 'forget', 'ATM', 'PIN']
# ['Who', 'I', 'contact', 'card', 'lost', 'stolen']
# ['Can', 'ATM', 'PIN', 'changed']
# ['Do', 'I', 'need', 'M', '&', 'N', 'Bank', 'account', 'purchase', 'M', '&', 'N', 'Bank', 'Giftplus', 'card']
# ['Are', 'transactions', 'I', 'use', 'Card']
# ['What', 'M', '&', 'N', 'Bank', 'Giftplus', 'card']
# ['How', 'soon', 'I', 'get', 'FoodPlus', 'card']
# ['Will', 'I', 'able', 'Transfer', 'money', 'Food', 'plus', 'card', 'account', 'account']
# ['What', 'happens', 'PIN', 'forgotten']
# ['What', 'M', '&', 'N', 'Bank', "'s", 'FoodPlus', 'card']
# ['What', 'I', 'need', 'know', 'M', '&', 'N', 'Bank', 'FoodPlus', 'Card']
# ['Can', 'I', 'use', 'card', 'withdraw', 'cash']
# ['How', 'I', 'load/reload', 'FoodPlus', 'card']
# ['Is', 'load', 'amount', 'limit']
# ['Is', 'usage', 'limit']
# ['How', 'soon', 'I', 'get', 'MoneyPlus', 'card']
# ['Is', 'load', 'amount', 'limit']
# ['What', 'M', '&', 'N', 'Bank', 'MoneyPlus', 'Card']
# ['How', 'I', 'top', 'value', 'card']
# ['How', 'set', 'ATM', 'PIN']
# ['What', 'options', 'I', 'choose', 'withdraw', 'cash', 'ATM']
# ['What', 'services', 'I', 'avail', 'GCAS']
# ['Do', 'I', 'need', 'load', 'currencies', 'card']
# ['How', 'I', 'avail', 'Global', 'Customer', 'Assistance', 'Services', '(', 'GCAS', ')', 'M', '&', 'N', 'Bank', 'Multi', 'Currency', 'ForexPlus', 'Platinum', 'Card']
# ['Do', 'I', 'need', 'pay', 'additional', 'amount', 'Cash', 'withdrawal', 'Charges', 'levied', 'M', '&', 'N', 'Bank', 'ATM', 'transactions']
# ['What', 'I', 'dont', 'sufficient', 'balance', 'wallet', 'corresponding', 'currency', 'transaction']
# ['What', 'I', 'forget', 'lose', 'activation', 'code']
# ['Do', 'I', 'need', 'M', '&', 'N', 'Bank', 'account', 'purchase', 'M', '&', 'N', 'Bank', 'Multi', 'Currency', 'ForexPlus', 'Platinum', 'Card']
# ['What', 'activation', 'code']
# ['What', 'validity', 'period', 'Card']
# ['Which', 'currencies', 'I', 'carry', 'card']
# ['Whom', 'I', 'contact', 'Card', 'lost', 'stolen']
# ['Can', 'value', 'Card', 'topped']
# ['Can', 'Card', 'used', 'India']
# ['How', 'much', 'Foreign', 'exchange', 'I', 'load', 'card']
# ['How', 'Card', 'work']
# ['How', 'I', 'get', 'activation', 'code']
# ['How', 'I', 'get', 'NetBanking', 'PIN']
# ['How', 'many', 'currencies', 'I', 'carry', 'card']
# ['Are', 'transactions', 'Card', 'used']
# ['Can', 'I', 'get', 'refund', 'towards', 'residual', 'Forex', 'return']
# ['Can', 'I', 'reload', 'Card', 'I', 'abroad']
# ['Can', 'I', 'transfer', 'currency', 'Card', 'one', 'wallet']
# ['Can', 'I', 'use', 'Card', 'pay', 'currency']
# ['What', 'I', 'Forget', 'Activation', 'Code']
# ['How', 'I', 'cancel', 'Multicurrency', 'Platinum', 'ForexPlus', 'Card']
# ['Do', 'I', 'need', 'M', '&', 'N', 'Bank', 'account', 'purchase', 'Multicurrency', 'Platinum', 'ForexPlus', 'Chip', 'card']
# ['What', 'documents', 'I', 'submit', 'I', 'purchase', 'M', '&', 'N', 'Bank', 'Multicurrency', 'Platinum', 'ForexPlus', 'Chip', 'card']
# ['What', 'maximum', 'value', 'Card', 'used']
# ['Is', 'Multicurrency', 'Platinum', 'ForexPlus', 'Chip', 'card', 'enabled', 'Verified', 'VISA', '(', 'VBV', ')']
# ['What', 'happens', 'card', 'lost']
# ['Can', 'value', 'card', 'topped']
# ['Can', 'I', 'use', 'card', 'pay', 'currency']
# ['Do', 'I', 'need', 'activate', 'Multicurrency', 'Platinum', 'ForexPlus', 'Chip', 'card', 'Ecommerce', 'transactions']
# ['Can', 'I', 'issue', 'cheques', 'load', 'Multicurrency', 'Platinum', 'ForexPlus', 'Chip', 'card']
# ['Are', 'extra', 'charges', 'aware']
# ['I', "'m", 'traveller', ',', 'I', 'still', 'benefit', 'Multicurrency', 'Card']
# ['What', 'customer', 'passing', 'terminal', 'Contactless', 'transaction', 'takes', 'place']
# ['Is', 'difference', 'process', 'ATM', 'Internet', 'transaction', 'Contactless', 'Card']
# ['What', 'services', 'I', 'avail', 'GCAS']
# ['What', 'I', 'forget', 'ATM', 'PIN']
# ['Which', 'currencies', 'loaded', 'card']
# ['How', 'much', 'currency', 'conversion', 'service', 'tax', 'applicable', 'time', 'Load', ',', 'Reload', 'Refund']
# ['How', 'set', 'Prepaid', 'NetBanking', 'Login', 'User', 'ID', '/', 'Password', 'first', 'time']
# ['What', 'authorization', 'scenarios']
# ['How', 'I', 'check', 'balance', 'M', '&', 'N', 'Bank', 'Multicurrency', 'ForexPlus', 'Chip', 'card']
# ['Are', 'transactions', 'Card', 'used']
# ['Do', 'I', 'need', 'pay', 'additional', 'amount', 'Cash', 'withdrawal', 'Charges', 'levied', 'M', '&', 'N', 'Bank', 'ATM', 'transaction']
# ['What', 'DCC/', 'MCC', 'stand']
# ['How', 'use', 'Contactless', 'Mutlicurrency', 'ForexPlus', 'Card']
# ['What', 'M', '&', 'N', 'Bank', 'Contactless', 'MulticurrencyForexPlus', 'card']
# ['How', 'many', 'days', 'advance', 'I', 'purchase', 'foreign', 'exchange']
# ['How', 'I', 'know', 'ATM', 'accept', 'Multicurrency', 'Card']
# ['Where', 'I', 'get', 'card']
# ['Can', 'I', 'use', 'DCC/', 'MCC', 'option', 'time', 'transaction']
# ['How', 'I', 'avail', 'Global', 'Customer', 'Assistance', 'Services', '(', 'GCAS', ')', 'Multicurrency', 'Card']
# ['What', 'exchange', 'rates', 'applicable', 'I', 'use', 'Travel', 'Card', 'transactions', '(', 'Cash', 'withdrawal', 'ATMs', 'point', 'sale', 'transactions', 'Merchant', 'Outlets', ')']
# ['How', 'Contactless', 'MultiCurrency', 'ForexPlus', 'card', 'work']
# ['Can', 'I', 'load', 'multiple', 'currencies', 'one', 'Multicurrency', 'Platinum', 'ForexPlus', 'Chip', 'card']
# ['What', 'I', 'Multicurrency', 'Platinum', 'ForexPlus', 'Chip', 'card', 'expired', 'unutilised', 'balance', 'card']
# ['What', 'balance', 'currency', 'transaction', 'goes']
# ['How', 'card', 'work']
# ['What', 'charges', 'towards', 'availing', 'GCAS', 'services']
# ['What', 'I', 'contact', 'card', 'lost']
# ['Can', 'I', 'load', 'Hajj', 'Umrah', 'ForexPlus', 'card', 'making', 'payment', 'Cash']
# ['I', "'m", 'traveller', ',', 'I', 'still', 'benefit', 'Hajj', 'Umrah', 'ForexPlus', 'Card']
# ['Are', 'transactions', 'card', 'used']
# ['Can', 'I', 'issue', 'cheques', 'load', 'Hajj', 'Umrah', 'ForexPlus', 'Card']
# ['What', 'M', '&', 'N', 'Bank', 'Hajj', 'Umrah', 'ForexPlus', 'card']
# ['What', 'documents', 'I', 'submit', 'I', 'purchase', 'M', '&', 'N', 'Bank', 'Hajj', 'Umrah', 'ForexPlus', 'card']
# ['Do', 'I', 'need', 'M', '&', 'N', 'Bank', 'account', 'purchase', 'Hajj', 'Umrah', 'ForexPlus', 'Card']
# ['What', 'maximum', 'value', 'Card', 'used']
# ['How', 'card', 'work']
# ['What', 'currencies', 'available']
# ['Where', 'I', 'get', 'card']
# ['What', 'M', '&', 'N', 'Bank', 'Apollo', 'Medical', 'Benefits', 'Card']
# ['Where', 'I', 'contact', 'offers/service', 'related', 'issues']
# ['Where', 'I', 'contact', 'card', 'transaction', 'related', 'issue']
# ['How', 'soon', 'I', 'get', 'M', '&', 'N', 'Bank', 'Apollo', 'Medical', 'Benefits', 'Card']
# ['Is', 'usage', 'limit']
# ['Is', 'load', 'amount', 'limit']
# ['How', 'I', 'top', 'value', 'card']
# ['In', 'case', 'card', 'lost', 'stolen', 'misused', 'I', 'hotlist', 'card']
# ['Can', 'I', 'use', 'Medical', 'benefit', 'card', 'outside', 'India']
# ['Where', 'I', 'use', 'card']
# ['Where', 'I', 'view', 'card', 'balance', 'card', 'history']
# ['Where', 'I', 'get', 'card']
# ['Whom', 'I', 'contact', 'card', 'lost', 'stolen']
# ['How', 'I', 'check', 'balance', 'M', '&', 'N', 'Bank', 'ISIC', 'ForexPlus', 'Chip', 'Card']
# ['How', 'much', 'foreign', 'exchange', 'I', 'retain', 'foreign', 'trip']
# ['What', 'happens', 'card', 'lost']
# ['How', 'I', 'top-up', 'value', 'card', 'I', 'abroad']
# ['What', 'documents', 'I', 'submit', 'I', 'purchase', 'ISIC', 'M', '&', 'N', 'Bank', 'ForexPlus', 'Card']
# ['I', 'renewed', 'passport', 'new', 'number', '.', 'Do', 'I', 'need', 'update', 'new', 'Passport', 'number', 'ISIC', 'ForexPlus', 'Chip', 'Card']
# ['Can', 'I', 'issue', 'Cheque', 'loading', 'ISIC', 'M', '&', 'N', 'Bank', 'ForexPlus', 'Card']
# ['How', 'I', 'know', 'ATM', 'accept', 'ISIC', 'M', '&', 'N', 'Bank', 'ForexPlus', 'Card']
# ['What', 'validity', 'ISIC', 'M', '&', 'N', 'Bank', 'ForexPlus', 'Card']
# ['Do', 'I', 'need', 'M', '&', 'N', 'Bank', 'account', 'purchase', 'ISIC', 'M', '&', 'N', 'Bank', 'ForexPlus', 'Chip', 'Card']
# ['What', 'DCC/', 'MCC', 'stand']
# ['What', 'I', 'forget', 'ATM', 'PIN']
# ['How', 'get', 'card', 'reissued', 'post', 'expiry', 'ISIC', 'ForexPlus', 'Chip', 'Card']
# ['Can', 'ATM', 'PIN', 'changed']
# ['How', 'soon', 'card', 'used', 'purchased']
# ['How', 'I', 'cancel', 'ISIC', 'M', '&', 'N', 'Bank', 'ForexPlus', 'Card']
# ['How', 'card', 'work']
# ['What', 'ISIC', 'M', '&', 'N', 'Bank', 'ForexPlus', 'card']
# ['How', 'I', 'activate', 'e-commerce']
# ['How', 'I', 'top-up', 'value', 'card', 'I', 'abroad']
# ['Can', 'non', 'Traveller', 'purchase', 'ISIC', 'ForexPlus', 'Card']
# ['Can', 'I', 'load', 'ISIC', 'ForexPlus', 'card', 'making', 'payment', 'Cash']
# ['What', 'I', 'need', 'know', 'ISIC', 'M', '&', 'N', 'Bank', 'ForexPlus', 'Card']
# ['Are', 'transactions', 'Card', 'used']
# ['Do', 'I', 'need', 'pay', 'additional', 'amount', 'Cash', 'withdrawal', 'Charges', 'levied', 'M', '&', 'N', 'Bank', 'ATM', 'transaction']
# ['What', 'currencies', 'available']
# ['Can', 'I', 'use', 'DCC/', 'MCC', 'option', 'time', 'transaction']
# ['How', 'many', 'days', 'advance', 'I', 'purchase', 'foreign', 'exchange']
# ['Can', 'value', 'card', 'topped']
# ['What', 'maximum', 'value', 'Card', 'used']
# ['What', 'VBV', 'Password']
# ...
# ['What', 'charges', 'I', 'pay', 'change', 'mode', 'repayment/', 'account', 'loan']
# ['What', 'charges', 'I', 'need', 'pay', 'foreclose', 'Loan', 'Against', 'Property']
# ['What', 'charges', 'I', 'need', 'pay', 'foreclose', 'loan']
# ['How', 'much', 'time', 'take', 'decision', 'application', 'Loan', 'Against', 'Property']
# ['What', 'De-pledge']
# ['What', 'Guarantor']
# ['What', 'Amortization']
# ['What', 'Pledge']
# ['What', 'RTGS']
# ['What', 'NEFT']
# ['What', 'SI']
# ['What', 'CIBIL']
# ['Which', 'documents', 'I', 'carry', 'time', 'visiting', 'M', '&', 'N', 'bank']
# ['Who', 'resolve', 'queries']
# ['How', 'I', 'obtain', 'NOC', 'bank', 'Registration', 'Certificate', 'mutilated', 'I', 'wish', 'apply', 'duplicate', 'Registration', 'Certificate', 'book', 'vehicle', 'finance', 'M', '&', 'N', 'Bank']
# ['How', 'I', 'obtain', 'NOC', 'bank', 'I', 'lost', 'Registration', 'Certificate', 'book', 'vehicle', 'finance', 'M', '&', 'N', 'Bank']
# ['How', 'I', 'obtain', 'NOC', 'bank', 'settling', 'partial', 'loss', 'Insurance', 'Claim', 'vehicle', 'finance', 'M', '&', 'N', 'Bank']
# ['How', 'I', 'obtain', 'NOC', 'bank', 'fitting', 'LPG/CNG', 'kit', 'vehicle', 'finance', 'M', '&', 'N', 'Bank']
# ['How', 'I', 'get', 'address', 'changed', 'loan', 'account']
# ['What', 'different', 'loan', 'repayment', 'modes']
# ['If', 'I', 'shares', 'one', 'company', ',', 'I', 'get', 'limit', 'one', 'script']
# ['How', 'I', 'obtain', 'Duplicate', 'Repayment', 'Schedule', 'loan', 'account']
# ['What', 'done', 'post', 'dated', 'cheques', 'I', 'request', 'change', 'mode', 'repayment/account', 'loan']
# ['How', 'I', 'obtain', 'duplicate', 'NOC/Form', '35', 'vehicle', 'loan', 'closed', 'fully', 'repaid']
# ['How', 'I', 'change', 'mode', 'repayment/', 'account', 'loan']
# ['Are', 'additional', 'charges', 'loan', 'repayment']
# ['Can', 'I', 'repay', 'loan', 'earlier', 'due', 'date']
# ['What', 'benefits', 'I', 'get', 'Loan', 'Against', 'Securities', 'Account']
# ['Is', 'overdraft', 'limit', 'fixed']
# ['Is', 'charge', 'LAS', 'Account', 'limits']
# ['How', 'I', 'get', 'securities', 'released']
# ['What', 'procedure', 'get', 'TRF', 'booklet']
# ['How', 'would', 'I', 'pay', 'interest', 'debited', 'Loan', 'Against', 'Securities', 'account', 'month']
# ['Do', 'I', 'get', 'statements', 'account']
# ['What', 'minimum', 'Loan', 'value']
# ['How', 'frequently', 'portfolio', 're-valued']
# ['Would', 'shares', 'held', 'name']
# ['What', 'documents', 'required', 'avail', 'Loans', 'Against', 'Rental', 'Receivables']
# ['How', 'much', 'loan', 'offered', 'Property']
# ['How', 'I', 'apply', 'Loan', 'Against', 'Rent', 'Receivables', '(', 'LARR', ')']
# ['What', 'Fees', 'Charges', 'applicable']
# ['How', 'much', 'time', 'take', 'decision', 'application', 'Loan', 'Against', 'Rental', 'Receivables']
# ['What', 'EMI']
# ['Are', 'additional', 'charges', 'loan', 'Prepayment']
# ['What', 'charges', 'I', 'need', 'pay', 'foreclose', 'Loans', 'Against', 'Rental', 'Receivable']
# ['How', 'I', 'make', 'request', 'foreclose', 'Loans', 'Against', 'Rental', 'Receivables', 'account']
# ['How', 'I', 'apply', 'duplicate', 'NOC/', 'closure', 'letter']
# ['What', 'Property', 'considered', 'collateral', 'LARR']
# ['What', 'maximum', 'tenure', 'repay', 'Loans', 'Against', 'Rental', 'Receivables']
# ['How', 'long', 'take', 'Professional', 'loan', 'processed']
# ['Can', 'I', 'repay', 'loan', 'earlier', 'Professionals', 'Loan']
# ['How', 'I', 'get', 'address', 'changed', 'loan', 'account']
# ['What', 'done', 'post', 'dated', 'cheques', 'I', 'request', 'change', 'mode', 'repayment/', 'account', 'loan']
# ['What', 'charges', 'I', 'pay', 'change', 'mode', 'repayment/', 'account', 'loan']
# ['How', 'I', 'change', 'mode', 'repayment/', 'account', 'loan']
# ['How', 'I', 'obtain', 'Duplicate', 'Repayment', 'Schedule', 'loan', 'account']
# ['What', 'security', 'I', 'need', 'provide', 'obtain', 'Professionals', 'loan']
# ['What', 'loan', 'tenure', 'options', 'Professionals', 'Loan']
# ['What', 'benefits', 'Current/Saving', 'Account', 'Loan', 'Professionals']
# ['How', 'much', 'loan', 'I', 'avail', 'Professionals']
# ['How', 'I', 'repay', 'Professionals', 'loan']
# ['How', 'long', 'I', 'take', 'repay', 'personal', 'loan']
# ['How', 'much', 'I', 'borrow']
# ['How', 'I', 'repay', 'Personal', 'Loan']
# ['Is', 'part-prepayment', 'Personal', 'Loan', 'allowed']
# ['How', 'Salary', 'Account', 'help', 'get', 'personal', 'loan']
# ['Do', 'I', 'need', 'provide', 'security', 'collateral', 'obtain', 'personal', 'loan', 'M', '&', 'N', 'Bank']
# ['What', 'De-pledge']
# ['What', 'Guarantor']
# ['What', 'Amortization']
# ['What', 'Pledge']
# ['What', 'RTGS']
# ['What', 'NEFT']
# ['What', 'SI']
# ['What', 'CIBIL']
# ['Can', 'I', 'repay', 'Personal', 'loan', 'earlier']
# ['Which', 'documents', 'I', 'carry', 'time', 'visiting', 'M', '&', 'N', 'bank']
# ['Who', 'resolve', 'queries']
# ['What', 'done', 'post', 'dated', 'cheques', 'I', 'request', 'change', 'mode', 'repayment/account', 'loan']
# ['How', 'I', 'change', 'mode', 'repayment/', 'account', 'loan']
# ['How', 'I', 'get', 'address', 'changed', 'loan', 'account']
# ['How', 'I', 'obtain', 'Duplicate', 'Repayment', 'Schedule', 'loan', 'account']
# ['What', 'charges', 'I', 'pay', 'change', 'mode', 'repayment/', 'account', 'loan']
# ['Are', 'additional', 'charges', 'loan', 'repayment']
# ['How', 'long', 'take', 'Personal', 'loan', 'processed']
# ['What', 'De-pledge']
# ['What', 'Guarantor']
# ['What', 'Amortization']
# ['What', 'Pledge']
# ['What', 'RTGS']
# ['What', 'NEFT']
# ['What', 'SI']
# ['What', 'CIBIL']
# ['Which', 'documents', 'I', 'carry', 'time', 'visiting', 'M', '&', 'N', 'bank']
# ['Who', 'resolve', 'queries']
# ['How', 'I', 'obtain', 'NOC', 'bank', 'settling', 'partial', 'loss', 'Insurance', 'Claim', 'vehicle', 'finance', 'M', '&', 'N', 'Bank']
# ['How', 'I', 'obtain', 'NOC', 'bank', 'Registration', 'Certificate', 'mutilated', 'I', 'wish', 'apply', 'duplicate', 'Registration', 'Certificate', 'book', 'vehicle', 'finance', 'M', '&', 'N', 'Bank']
# ['How', 'I', 'obtain', 'NOC', 'bank', 'I', 'lost', 'Registration', 'Certificate', 'book', 'vehicle', 'finance', 'M', '&', 'N', 'Bank']
# ['How', 'I', 'obtain', 'duplicate', 'NOC/Form', '35', 'vehicle', 'loan', 'closed', 'fully', 'repaid']
# ['How', 'I', 'get', 'address', 'changed', 'loan', 'account']
# ['What', 'done', 'post', 'dated', 'cheques', 'I', 'request', 'change', 'mode', 'repayment/account', 'loan']
# ['How', 'I', 'change', 'mode', 'repayment/', 'account', 'loan']
# ['Who', 'eligible', 'tractor', 'loan']
# ['Can', 'I', 'get', 'tractor', 'loan', 'tractor', 'I', 'want', 'purchase']
# ['What', 'different', 'modes', 'loan', 'repayment']
# ['Can', 'I', 'pre-pay', 'entire', 'loan', 'amount']
# ['Do', 'want', 'repay', 'loan', 'earlier', 'due', 'date']
# ['Is', 'guarantor', 'required']
# ['What', 'I', 'want', 'repay', 'loan', 'earlier', 'due', 'date']
# ['What', 'maximum', 'loan', 'amount', 'I', 'take', 'Tractor', 'Loan']
# ['How', 'I', 'obtain', 'duplicate', 'NOC/Form', '35', 'vehicle', 'loan', 'closed', 'fully', 'repaid']
# ['How', 'I', 'change', 'mode', 'repayment/', 'account', 'loan']
# ['How', 'I', 'get', 'address', 'changed', 'loan', 'account']
# ['How', 'I', 'obtain', 'NOC', 'bank', 'settling', 'partial', 'loss', 'Insurance', 'Claim', 'vehicle', 'finance', 'M', '&', 'N', 'Bank']
# ['What', 'charges', 'I', 'pay', 'change', 'mode', 'repayment/', 'account', 'loan']
# ['How', 'I', 'obtain', 'NOC', 'bank', 'Registration', 'Certificate', 'mutilated', 'I', 'wish', 'apply', 'duplicate', 'Registration', 'Certificate', 'book', 'vehicle', 'finance', 'M', '&', 'N', 'Bank']
# ['How', 'I', 'obtain', 'NOC', 'bank', 'I', 'lost', 'Registration', 'Certificate', 'book', 'vehicle', 'finance', 'M', '&', 'N', 'Bank']
# ['What', 'done', 'post-dated', 'cheques', 'I', 'request', 'change', 'mode', 'repayment/account', 'loan']
# ['How', 'I', 'utilize', 'amount']
# ['How', 'many', 'salary', 'credits', 'required', 'existing', 'account', 'qualify', 'SmartDraft']
# ['What', 'amount', 'I', 'get', 'overdraft']
# ['When', 'SmartDraft', 'limit', 'renewed']
# ['Which', 'locations', 'SmartDraft', 'available']
# ['Am', 'I', 'eligible', 'SmartDraft']
# ['What', 'De-pledge']
# ['What', 'Guarantor']
# ['What', 'Amortization']
# ['What', 'Pledge']
# ['What', 'RTGS']
# ['What', 'NEFT']
# ['What', 'SI']
# ['What', 'CIBIL']
# ['Which', 'documents', 'I', 'carry', 'time', 'visiting', 'M', '&', 'N', 'bank']
# ['Who', 'resolve', 'queries']
# ['How', 'I', 'get', 'address', 'changed', 'loan', 'account']
# ['How', 'I', 'obtain', 'duplicate', 'NOC/Form', '35', 'vehicle', 'loan', 'closed', 'fully', 'repaid']
# ['How', 'I', 'obtain', 'NOC', 'bank', 'fitting', 'LPG/CNG', 'kit', 'vehicle', 'finance', 'M', '&', 'N', 'Bank']
# ['How', 'I', 'obtain', 'NOC', 'bank', 'settling', 'partial', 'loss', 'Insurance', 'Claim', 'vehicle', 'finance', 'M', '&', 'N', 'Bank']
# ['How', 'I', 'obtain', 'NOC', 'bank', 'I', 'lost', 'Registration', 'Certificate', 'book', 'vehicle', 'finance', 'M', '&', 'N', 'Bank']
# ['How', 'I', 'obtain', 'NOC', 'bank', 'Registration', 'Certificate', 'mutilated', 'I', 'wish', 'apply', 'duplicate', 'Registration', 'Certificate', 'book', 'vehicle', 'finance', 'M', '&', 'N', 'Bank']
# ['How', 'I', 'obtain', 'Duplicate', 'Repayment', 'Schedule', 'loan', 'account']
# ['How', 'I', 'change', 'mode', 'repayment/', 'account', 'loan']
# ['What', 'charges', 'I', 'pay', 'change', 'mode', 'repayment/', 'account', 'loan']
# ['What', 'done', 'post-dated', 'cheques', 'I', 'request', 'change', 'mode', 'repayment/', 'account', 'loan']
# ['How', 'much', 'finance', 'I', 'avail']
# ['Do', 'I', 'option', 'pre-pay', 'entire', 'loan', 'amount']
# ['How', 'long', 'take', 'process', 'loan']
# ['How', 'much', 'time', 'take', 'change', 'mode', 'repayment/', 'account', 'repayment', 'loan']
# ['In', 'ways', 'I', 'get', 'touch', 'bank', 'details', 'Two', 'Wheeler', 'Loans']
# ['If', 'I', 'dont', 'account', 'M', '&', 'N', 'Bank', ',', 'I', 'still', 'avail', 'loans']
# ['Do', 'I', 'need', 'guarantor']
# ['How', 'I', 'obtain', 'NOC', 'bank', 'Registration', 'Certificate', 'mutilated', 'I', 'wish', 'apply', 'duplicate', 'Registration', 'Certificate', 'book', 'vehicle', 'finance', 'M', '&', 'N', 'Bank']
# ['How', 'I', 'obtain', 'duplicate', 'NOC/Form', '35', 'vehicle', 'loan', 'closed', 'fully', 'repaid']
# ['What', 'done', 'post-dated', 'cheques', 'I', 'request', 'change', 'mode', 'repayment/', 'account', 'loan']
# ['How', 'I', 'obtain', 'NOC', 'bank', 'settling', 'partial', 'loss', 'Insurance', 'Claim', 'vehicle', 'finance', 'M', '&', 'N', 'Bank']
# ['How', 'I', 'obtain', 'NOC', 'bank', 'I', 'lost', 'Registration', 'Certificate', 'book', 'vehicle', 'finance', 'M', '&', 'N', 'Bank']
# ['How', 'I', 'get', 'address', 'changed', 'loan', 'account']
# ['How', 'I', 'obtain', 'NOC', 'bank', 'fitting', 'LPG/CNG', 'kit', 'vehicle', 'finance', 'M', '&', 'N', 'Bank']
# ['How', 'I', 'change', 'mode', 'repayment/', 'account', 'loan']
# ['How', 'I', 'obtain', 'Duplicate', 'Repayment', 'Schedule', 'loan', 'account']
# ['What', 'charges', 'I', 'pay', 'change', 'mode', 'repayment/', 'account', 'loan']
# ['Do', 'I', 'need', 'enter', '#', 'keying', 'Card', 'number/', 'Card', 'expiry', 'date/', 'CVV', 'number']
# ['What', 'details', 'required', 'I', 'want', 'perform', 'secure', 'IVR', 'transaction']
# ['How', 'I', 'get', 'IVR', 'Password', 'I', 'hold', 'add-on', 'card']
# ['How', 'I', 'register', 'Mobile', 'number', 'IVR', 'Password']
# ['How', 'I', 'obtain', 'IVR', 'Password']
# ['Can', 'I', 'use', 'IVR', 'Password', 'perform', 'multiple', 'transactions']
# ['Can', 'I', 'generate', 'multiple', 'IVR', 'Passwords']
# ['How', 'I', 'register', 'IVR', 'password']
# ['What', 'IVR', 'Password', 'work']
# ['In', 'much', 'time', 'IVR', 'Password', 'delivered', 'mobile', 'phone/email', 'ID']
# ['Can', 'OTP', 'generated', 'prior', 'transaction']
# ['Can', 'I', 'continue', 'using', 'Verified', 'Visa/MasterCard', 'SecureCode/Protectbuy', 'password', 'online', 'transactions']
# ['On', 'mobile', 'number', 'I', 'receive', 'OTP']
# ['Is', 'necessary', 'register', 'card', 'OTP', 'transaction']
# ['Is', 'option', 'available', 'online', 'transactions']
# ['Can', 'OTP', 'used', 'multiple', 'online', 'transactions']
# ['How', 'OTP', 'sent', 'customers']
# ['What', 'validity', 'period', 'OTP']
# ['What', 'happens', 'I', 'shop', 'Verified', 'Visa/', 'MasterCard', 'SecureCode', 'merchant', 'website', 'I', "'m", 'registered', 'feature']
# ['Where', 'I', 'shop', 'Verified', 'Visa']
# ['How', 'online', 'store', 'know', 'I', 'Verified', 'Visa/', 'MasterCard', 'SecureCode']
# ['How', 'I', 'register', '/', 're-set', 'password', 'VBV/MSC', 'mobile', 'number/', 'email', 'ID', 'updated', 'bank', "'s", 'records']
# ['Once', 'I', 'registered', ',', 'long', 'take', 'Verified', 'Visa', '/', 'MasterCard', 'SecureCode', 'become', 'active', 'card']
# ['What', 'happen', 'I', 'try', 'register', '&', 'generate', 'OTP', 'within', '2', 'hours']
# ['If', 'account', 'blocked', ',', 'I', 'unblock']
# ['How', 'I', 'use', 'Verified', 'Visa', '/', 'MasterCard', 'SecureCode', 'I', 'shop', 'online', ',', 'Im', 'registered']
# ['How', 'Verified', 'Visa/', 'MasterCard', 'SecureCode', 'work']
# ['I', 'suspect', 'someone', 'stolen', 'password', 'used', 'make', 'fraudulent', 'purchases', '.', 'What', 'I']
# ['My', 'spouse', 'I', 'card', 'number', '.', 'How', 'Verified', 'Visa/', 'MasterCard', 'SecureCode', 'work', 'us']
# ['What', 'Verified', 'Visa/MasterCard', 'SecureCode']
# ['How', 'I', 'register', 'M', '&', 'N', 'Bank', 'Card']
# ['Can', 'I', 'register', 'Verified', 'Visa/MasterCard', 'SecureCode', 'existing', 'M', '&', 'N', 'Bank', 'Card', 'I', 'need', 'apply', 'new', 'one']
# ['Can', 'I', 'register', 'one', 'M', '&', 'N', 'Bank', 'Credit/', 'Debit', 'Card']
# ['If', 'I', 'received', 'renewed', 'card', ',', 'I', 'need', 're-register']
# ['Can', 'I', 'register', 'non-Visa', 'payment', 'Cards', 'Verified', 'Visa', 'non-', 'MasterCard', 'payment', 'Cards', 'MasterCard', 'SecureCode']
# ['Can', 'I', 'use', 'Verified', 'Visa/', 'MasterCard', 'SecureCode', 'computer']
# ['Do', 'I', 'need', 'special', 'equipment', 'software', 'computer']
# ['What', 'Personal', 'Assurance', 'Message', 'Personal', 'Greeting']
# ['How', 'I', 'register', 'VBV/SC', 'mobile', 'number', '/', 'Email', 'ID', 'updated', 'Credit', 'Card', 'records', 'Bank']
# ['How', 'long', 'take', 'IVR', 'Password', 'get', 'delivered', 'using', 'Verified', 'Visa/Mastercard', 'Secure', 'Code']
# ['If', 'I', 'registered', 'two', 'email', 'IDs', ',', 'email', 'ID', 'I', 'receive', 'IVR', 'Password']
# ['What', 'validity', 'IVR', 'Password', 'using', 'Verified', 'Visa/Mastercard', 'Secure', 'Code']
# ['What', 'things', 'I', 'need', 'keep', 'mind', 'IVR', 'Password', 'using', 'Verified', 'Visa/Mastercard', 'Secure', 'Code']
# ['In', 'transactions', 'One', 'Time', 'Password', '(', 'IVR', 'Password', ')', 'process', 'applicable']
# ['I', "n't", 'see', 'Personal', 'Assurance', 'Message', 'Secure', 'page', '.', 'What', 'I']
# ['If', 'I', 'forget', 'VBV/MSC', 'password', ',', 'I', 'retrieve']
# ['While', 'trying', 'register', 'card', ',', 'I', 'getting', 'error', 'message', 'stating', 'mobile', '.', 'mismatch', ',', 'could', 'reason']
# ['On', 'email', 'id', 'I', 'receive', 'OTP', 'Credit', 'card', 'registration', 'password', 'reset']
# ['While', 'trying', 'register', 'I', 'getting', 'error', 'message', 'Card', 'already', 'enrolled', ',', 'I']
# ['I', "n't", 'remember', 'Verified', 'Visa', '/', 'MasterCard', 'Securecode', 'login', 'Id']
# ['Where', 'I', 'find', 'CVV2']
# ['I', 'unable', 'transact', 'online', 'card', 'de-registered', 'status', ',', 'I', 're-register', 'card']
# ['Is', 'fee', 'register', 'Verified', 'Visa', '/', 'MasterCard', 'Securecode']
# ['What', 'steps', 'I', 'take', 'ensure', 'VBV', '/', 'MSC', 'Password', 'strong', 'difficult', 'guess']
# ['Can', 'I', 'set', 'Personal', 'Assurance', 'Message', 'VBV', '/', 'MSC', 'Password']
# ['What', 'happens', 'I', 'try', 'make', 'purchase', 'merchant', "n't", 'participate', 'Verified', 'Visa', '/', 'MasterCard', 'Securecode', 'service']
# ['Can', 'I', 'get', 'benefit', 'Verified', 'Visa/', 'MasterCard', 'SecureCode', 'security', 'online', 'stores', 'participating', 'service']
# ['Are', 'real']
# ['look', 'like']
# ['How', 'help']
# ['Which', 'languages', 'speak']
# ['much', 'interest', 'FD']
# ['much', 'interest', 'Fixed', 'Deposit']
# ['Fixed', 'Deposit']
# ['FD']

# %%
from keras.optimizer_v1 import SGD

tfv.fit(X)
le.fit(data['Class'])

X = tfv.transform(X)

y = le.transform(data['Class'])

trainx, testx, trainy, testy = tts(X, y, test_size=.3, random_state=42)


model = SGD()
model.fit(trainx, trainy)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2692/3917459589.py in <module>
#      12
#      13 model = SGD()
# ---> 14 model.fit(trainx, trainy)
#      15
#      16
#
# c:\users\houss\pycharmprojects\pythonproject\venv\lib\site-packages\keras\optimizer_v2\optimizer_v2.py in __getattribute__(self, name)
#     838       if name in self._hyper:
#     839         return self._get_hyper(name)
# --> 840       raise e
#     841
#     842   def __dir__(self):
#
# c:\users\houss\pycharmprojects\pythonproject\venv\lib\site-packages\keras\optimizer_v2\optimizer_v2.py in __getattribute__(self, name)
#     828     """Overridden to support hyperparameter access."""
#     829     try:
# --> 830       return super(OptimizerV2, self).__getattribute__(name)
#     831     except AttributeError as e:
#     832       # Needed to avoid infinite recursion with __setattr__.
#
# AttributeError: 'SGD' object has no attribute 'fit'

# %%
class_=le.inverse_transform(model.predict(X))

print("SVC:", model.score(testx, testy))

# %%
def get_max5(arr):
    ixarr = []
    for ix, el in enumerate(arr):
        ixarr.append((el, ix))


    ixarr.sort()
    ixs = []
    for i in ixarr[-5:]:

        ixs.append(i[1])

    return ixs[::-1]

def get_response(usrText):
    while True:

        if usrText.lower() == "bye":
            return "Bye"

        GREETING_INPUTS = ["hello", "hi", "greetings", "sup", "what's up", "hey","hiii","hii","yo"]

        a = [x.lower() for x in GREETING_INPUTS]

        sd=["Thanks","Welcome"]

        d = [x.lower() for x in sd]


        am=["OK"]

        c = [x.lower() for x in am]

        ty = ["getting"]
        r = [x.lower() for x in ty]



        t_usr = tfv.transform([cleanup(usrText.strip().lower())])
        class_ = le.inverse_transform(model.predict(t_usr))

        questionset = data[data['Class'].values == class_]

        cos_sims = []
        for question in questionset['Question']:
            sims = cosine_similarity(tfv.transform([question]), t_usr)

            cos_sims.append(sims)

        ind = cos_sims.index(max(cos_sims))

        b = [questionset.index[ind]]









        if usrText.lower() in a:

            return ("Hi, I'm Personal Chatbot!\U0001F60A")


        if usrText.lower() in c:
            return "Ok...Alright!\U0001F64C"

        if usrText.lower() in d:
            return ("My pleasure! \U0001F607")



        if max(cos_sims) > [[0.]]:
            a = data['Answer'][questionset.index[ind]]+"   "
            return a


        elif max(cos_sims)==[[0.]]:
           return "sorry! \U0001F605"



def get_response2(usr):
    if usr.lower() == "bye":
        return "Thanks for having conversation! \U0001F60E"

    GREETING_INPUTS = ["hello", "hi", "greetings", "sup", "what's up", "hey","hii","hiii","hiiiii","yo","Hey there"]

    a = [x.lower() for x in GREETING_INPUTS]

    sd = ["Thanks", "Welcome"]

    d = [x.lower() for x in sd]

    am = ["OK"]

    c = [x.lower() for x in am]



    t_usr = tfv.transform([cleanup(usr.strip().lower())])
    class_ = le.inverse_transform(model.predict(t_usr))

    questionset = data[data['Class'].values == class_]

    cos_sims = []
    for question in questionset['Question']:
        sims = cosine_similarity(tfv.transform([question]), t_usr)

        cos_sims.append(sims)
        print(max(cos_sims))

    ind = cos_sims.index(max(cos_sims))

    b = [questionset.index[ind]]

    if usr.lower() in a:
        return ("you can ask me questions related to: Accounts, Investments, Funds, etc.")

    if usr.lower() in c:
        return " Cool! \U0001f604"

    if usr.lower() in d:
        return ("\U0001F44D")




    if max(cos_sims) == [[0.]]:

        return "I'm not able to solve this question at this moment. You can call to customer support 1860 999 9999 \U0001F615"

    if max(cos_sims) > [[0.]]:

        inds = get_max5(cos_sims)
        print(inds)

        b = "1)" + data['Question'][questionset.index[0]]
        c = "\n2)" + data['Question'][questionset.index[1]]
        d = "\n3)" + data['Question'][questionset.index[2]]
        e = "\n4)" + data['Question'][questionset.index[3]]
        f = "\n5)" + data['Question'][questionset.index[4]]

        return "Following are the Recommended Questions:"+ b + c + d + e + f

# %%
get_response("chkounek nti ?")

# %%
import pickle
pickle.dump(model, open('data.pkl', 'wb'))
